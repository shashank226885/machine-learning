# %%
import pandas as pd
df=pd.read_csv("Car_sales.csv")
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.head(5)
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
df.shape
# Out:
# (157, 15)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
df.isnull().sum().idxmax
# Out:
# <bound method Series.idxmax of Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64>

# %%
# df.drop(columns="Manufacturer",inplace=True)

# %%
df.sort_values(by=("Price in thousands"),ascending=True)
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 2    Acura          CL                             14.114              18.225
# 33   Chrysler       Town & Country                 53.480               19.54
# 129  Saturn         SL                             80.620                 9.2
# 140  Toyota         Tacoma                         84.087               9.575
# 63   Hyundai        Elantra                        66.692               7.825
# ..             ...                ...                 ...                 ...
# 126  Porsche        Carrera Cabriolet               1.866               67.55
# 95   Mercedes-Benz  SL-Class                        3.311                58.6
# 99   Mercedes-Benz  CL500                           0.954                   .
# 26   Chevrolet      Metro                          21.855                5.16
# 62   Hyundai        Accent                         41.184                5.86
#
# ...

# %%
df["Price in thousands"]=pd.to_numeric(df["Price in thousands"],errors="coerce")

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.dropna(subset="Price in thousands",inplace=True)

# %%
df.iloc[0],df.iloc[-1]
# Out:
# (Manufacturer               Acura
#  Model                  Integra
#  Sales in thousands                16.919
#  4-year resale value                16.36
#  Vehicle type                   Passenger
#  Price in thousands                  21.5
#  Engine size                          1.8
#  Horsepower                           140
#  Wheelbase                          101.2
#  Width                               67.3
#  Length                             172.4
#  Curb weight                        2.639
#  Fuel capacity                       13.2
#  Fuel efficiency                       28
#  Latest Launch                   2-Feb-14
#  Name: 0, dtype: object,
#  Manufacturer               Volvo
#  Model                  S80
#  Sales in thousands                18.969
#  4-year resale value                    .
#  Vehicle type                   Passenger
#  Price in thousands                  36.0
#  Engine size                          2.9
#  Horsepower                           201
# ...

# %%
df.sort_values(by=("Price in thousands"),ascending=False)
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# 5    Audi           A6                             18.780              23.555
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.dropna(subset="Price in thousands",inplace=True)

# %%
df.iloc[0],df.iloc[-1]
# Out:
# (Manufacturer               Acura
#  Model                  Integra
#  Sales in thousands                16.919
#  4-year resale value                16.36
#  Vehicle type                   Passenger
#  Price in thousands                  21.5
#  Engine size                          1.8
#  Horsepower                           140
#  Wheelbase                          101.2
#  Width                               67.3
#  Length                             172.4
#  Curb weight                        2.639
#  Fuel capacity                       13.2
#  Fuel efficiency                       28
#  Latest Launch                   2-Feb-14
#  Name: 0, dtype: object,
#  Manufacturer               Volvo
#  Model                  S80
#  Sales in thousands                18.969
#  4-year resale value                    .
#  Vehicle type                   Passenger
#  Price in thousands                  36.0
#  Engine size                          2.9
#  Horsepower                           201
# ...

# %%
def min_max(df,col):
    return df[col].min(),df[col].max()

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands     float64
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
cols=["Length","Horsepower","Fuel efficiency"]
df[cols]=df[cols].apply(pd.to_numeric,errors="coerce")
for i in range(3):
    print(min_max(df,cols[i]))
# Out:
# (149.4, 224.5)
# (55, 450)
# (15.0, 45.0)

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands     float64
# Engine size             object
# Horsepower               int64
# Wheelbase               object
# Width                   object
# Length                 float64
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency        float64
# Latest Launch           object
# dtype: object

# %%
cols=df.select_dtypes(include="number").columns.tolist()
col
# Out:
# 'Fuel efficiency'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig,axes=plt.subplots(3,2,figsize=(8,8))
axes=axes.flatten()
for i,col in enumerate(cols):
    cur=axes[i]
    sns.histplot(data=df,x=col,ax=cur)
plt.delaxes(axes[-1])
plt.show()

# %%
sns.kdeplot(data=df,x="Length",fill=True)
# Out:
# <Axes: xlabel='Length', ylabel='Density'>

# %%
df["Manufacturer"].value_counts().reset_index()
# Out:
#             index  Manufacturer
# 0   Dodge                    11
# 1   Ford                     11
# 2   Toyota                    9
# 3   Mercedes-Benz             9
# 4   Chevrolet                 9
# 5   Mitsubishi                7
# 6   Nissan                    7
# 7   Chrysler                  6
# 8   Oldsmobile                6
# 9   Pontiac                   6
# 10  Lexus                     6
# 11  Mercury                   6
# 12  Volkswagen                6
# 13  Volvo                     6
# 14  Cadillac                  5
# 15  Honda                     5
# 16  Saturn                    5
# 17  Plymouth                  4
# 18  Buick                     4
# 19  Porsche                   3
# 20  Acura                     3
# 21  Audi                      3
# 22  Jeep                      3
# 23  Hyundai                   3
# 24  BMW                       3
# 25  Lincoln                   3
# 26  Saab                      2
# 27  Subaru                    2
# ...

# %%
d=df.select_dtypes(include="number").columns
d
# Out:
# Index(['Sales in thousands', 'Price in thousands', 'Horsepower', 'Length',
#        'Fuel efficiency'],
#       dtype='object')

# %%
df["Price in thousands"].corr(df["Sales in thousands"])
# Out:
# -0.3047344541294122

# %%
sns.scatterplot(data=df,x="Price in thousands",y="Sales in thousands")
# Out:
# <Axes: xlabel='Price in thousands', ylabel='Sales in thousands'>

# %%
sns.pairplot(df)

# %%
sns.boxplot(data=df,x="Manufacturer",y="Sales in thousands")
plt.xticks(rotation=45)
plt.show()

# %%
# df

# %%
d=df.select_dtypes(include="number").columns
d
# Out:
# Index(['Sales in thousands', 'Price in thousands', 'Horsepower', 'Length',
#        'Fuel efficiency'],
#       dtype='object')

# %%
cols=['Sales in thousands', 'Price in thousands', 'Horsepower', 'Length',
       'Fuel efficiency']
fig,axes=plt.subplots(3,2,figsize=(8,8))
axes=axes.flatten()
for i,col in enumerate(cols):
    cur=axes[i]
    sns.boxplot(data=df,x="Manufacturer",y=col,ax=cur)
plt.delaxes(axes[-1])
plt.show()

# %%
# df

# %%
x=df

# %%
x.drop(columns="Sales in thousands")
# Out:
#       Manufacturer              Model 4-year resale value Vehicle type  \
# 0    Acura          Integra                         16.36    Passenger
# 1    Acura          TL                             19.875    Passenger
# 3    Acura          RL                             29.725    Passenger
# 4    Audi           A4                             22.255    Passenger
# 5    Audi           A6                             23.555    Passenger
# ..             ...                ...                 ...          ...
# 152  Volvo          V40                                 .    Passenger
# 153  Volvo          S70                                 .    Passenger
# 154  Volvo          V70                                 .    Passenger
# 155  Volvo          C70                                 .    Passenger
# 156  Volvo          S80                                 .    Passenger
#
#      Price in thousands Engine size  Horsepower Wheelbase Width  Length  \
# ...

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# 5    Audi           A6                             18.780              23.555
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
y=df["Sales in thousands"]

# %%
y
# Out:
# 0      16.919
# 1      39.384
# 3       8.588
# 4      20.397
# 5      18.780
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales in thousands, Length: 155, dtype: float64
