# %%
import pandas as pd
df=pd.read_csv("nlp_train(1).csv")
df
# Out:
#                                                     text  target  \
# 0      I was wondering if anyone out there could enli...       7
# 1      A fair number of brave souls who upgraded thei...       4
# 2      well folks, my mac plus finally gave up the gh...       4
# 3      \nDo you have Weitek's address/phone number?  ...       1
# 4      From article <C5owCB.n3p@world.std.com>, by to...      14
# ...                                                  ...     ...
# 11309  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...      13
# 11310  I have a (very old) Mac 512k and a Mac Plus, b...       4
# 11311  I just installed a DX2-66 CPU in a clone mothe...       3
# 11312  \nWouldn't this require a hyper-sphere.  In 3-...       1
# 11313  Stolen from Pasadena between 4:30 and 6:30 pm ...       8
#
#                        category
# 0                     rec.autos
# 1         comp.sys.mac.hardware
# 2         comp.sys.mac.hardware
# 3                 comp.graphics
# ...

# %%
train_df=pd.read_csv("nlp_train(1).csv")
test_df=pd.read_csv("nlp_test(1).csv")
test_df
# Out:
#                                                    text  target  \
# 0     I am a little confused on all of the models of...       7
# 1     I'm not familiar at all with the format of the...       5
# 2                                   \nIn a word, yes.\n       0
# 3     \nThey were attacking the Iraqis to drive them...      17
# 4     \nI've just spent two solid months arguing tha...      19
# ...                                                 ...     ...
# 7527  \n   Henry, if I read you correctly, you may b...      14
# 7528  about\nthem on\n\nActually, I thought Macs wer...       4
# 7529  I sent a version of this post out a while ago,...       9
# 7530  I have this kit which includes the following :...       6
# 7531  \nFine, but one of the points of this entire d...      15
#
#                     category
# 0                  rec.autos
# 1             comp.windows.x
# 2                alt.atheism
# 3      talk.politics.mideast
# 4         talk.religion.misc
# ...

# %%
train_df
# Out:
#                                                     text  target  \
# 0      I was wondering if anyone out there could enli...       7
# 1      A fair number of brave souls who upgraded thei...       4
# 2      well folks, my mac plus finally gave up the gh...       4
# 3      \nDo you have Weitek's address/phone number?  ...       1
# 4      From article <C5owCB.n3p@world.std.com>, by to...      14
# ...                                                  ...     ...
# 11309  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...      13
# 11310  I have a (very old) Mac 512k and a Mac Plus, b...       4
# 11311  I just installed a DX2-66 CPU in a clone mothe...       3
# 11312  \nWouldn't this require a hyper-sphere.  In 3-...       1
# 11313  Stolen from Pasadena between 4:30 and 6:30 pm ...       8
#
#                        category
# 0                     rec.autos
# 1         comp.sys.mac.hardware
# 2         comp.sys.mac.hardware
# 3                 comp.graphics
# ...

# %%
print(test_df["target"].unique())
# Out:
# [ 7  5  0 17 19 13 15  1  2  8  4  6 16 14  3 11  9 10 18 12]

# %%
# test_df[(test_df["category"]=="alt.atheism")|(test_df["category"]=="com.graphics")|(test_df["category"]=="sci.space")]
test_df['category'].value_counts()
# Out:
# rec.sport.hockey            399
# soc.religion.christian      398
# rec.motorcycles             398
# rec.sport.baseball          397
# rec.autos                   396
# sci.crypt                   396
# sci.med                     396
# comp.windows.x              395
# sci.space                   394
# comp.os.ms-windows.misc     394
# sci.electronics             393
# comp.sys.ibm.pc.hardware    392
# misc.forsale                390
# comp.graphics               389
# comp.sys.mac.hardware       385
# talk.politics.mideast       376
# talk.politics.guns          364
# alt.atheism                 319
# talk.politics.misc          310
# talk.religion.misc          251
# Name: category, dtype: int64

# %%
cols=["sci.space","alt.atheism","comp.graphics"]
df=test_df[test_df["category"].isin(cols)]

# %%
for i in range(1000):
    if (test_df["category"].count):
        print(df.iloc[i])
# Out:
# text        \nIn a word, yes.\n
# target                        0
# category            alt.atheism
# Name: 2, dtype: object
# text        :  \n: well, i have lots of experience with sc...
# target                                                      1
# category                                        comp.graphics
# Name: 9, dtype: object
# text        \nProbably because it IS rape.\n\n\nSo nothing...
# target                                                      0
# category                                          alt.atheism
# Name: 14, dtype: object
# text        Hello,\ni'm interested in those devices too.\n...
# target                                                      1
# category                                        comp.graphics
# Name: 17, dtype: object
# text        This is an invitation to send articles to the ...
# target                                                      1
# category                                        comp.graphics
# Name: 20, dtype: object
# ...

# %%
df
# Out:
#                                                    text  target       category
# 2                                   \nIn a word, yes.\n       0    alt.atheism
# 9     :  \n: well, i have lots of experience with sc...       1  comp.graphics
# 14    \nProbably because it IS rape.\n\n\nSo nothing...       0    alt.atheism
# 17    Hello,\ni'm interested in those devices too.\n...       1  comp.graphics
# 20    This is an invitation to send articles to the ...       1  comp.graphics
# ...                                                 ...     ...            ...
# 7488  \n\namen.. I too have learned by example, spec...       1  comp.graphics
# 7492  \n: I agree, I had a hard feeling not believin...       0    alt.atheism
# 7496  \n\nYes a flotation tank, combined with florid...      14      sci.space
# 7505  Archive-name: atheism/overview\nAlt-atheism-ar...       0    alt.atheism
# 7527  \n   Henry, if I read you correctly, you may b...      14      sci.space
#
# [1102 rows x 3 columns]

# %%
test_df=df
test_df
# Out:
#                                                    text  target       category
# 2                                   \nIn a word, yes.\n       0    alt.atheism
# 9     :  \n: well, i have lots of experience with sc...       1  comp.graphics
# 14    \nProbably because it IS rape.\n\n\nSo nothing...       0    alt.atheism
# 17    Hello,\ni'm interested in those devices too.\n...       1  comp.graphics
# 20    This is an invitation to send articles to the ...       1  comp.graphics
# ...                                                 ...     ...            ...
# 7488  \n\namen.. I too have learned by example, spec...       1  comp.graphics
# 7492  \n: I agree, I had a hard feeling not believin...       0    alt.atheism
# 7496  \n\nYes a flotation tank, combined with florid...      14      sci.space
# 7505  Archive-name: atheism/overview\nAlt-atheism-ar...       0    alt.atheism
# 7527  \n   Henry, if I read you correctly, you may b...      14      sci.space
#
# [1102 rows x 3 columns]

# %%
train_df=df
train_df
# Out:
#                                                    text  target       category
# 2                                   \nIn a word, yes.\n       0    alt.atheism
# 9     :  \n: well, i have lots of experience with sc...       1  comp.graphics
# 14    \nProbably because it IS rape.\n\n\nSo nothing...       0    alt.atheism
# 17    Hello,\ni'm interested in those devices too.\n...       1  comp.graphics
# 20    This is an invitation to send articles to the ...       1  comp.graphics
# ...                                                 ...     ...            ...
# 7488  \n\namen.. I too have learned by example, spec...       1  comp.graphics
# 7492  \n: I agree, I had a hard feeling not believin...       0    alt.atheism
# 7496  \n\nYes a flotation tank, combined with florid...      14      sci.space
# 7505  Archive-name: atheism/overview\nAlt-atheism-ar...       0    alt.atheism
# 7527  \n   Henry, if I read you correctly, you may b...      14      sci.space
#
# [1102 rows x 3 columns]

# %%
train_df["target"].nunique()
# Out:
# 3

# %%
train_df["text"].isnull().sum()
# Out:
# 22

# %%
test_df.iloc[4:5,:]
# Out:
#                                                  text  target       category
# 20  This is an invitation to send articles to the ...       1  comp.graphics

# %%
train_df.dropna(subset=["text"],inplace=True)
# Out:
# /tmp/ipykernel_3661/2333787393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.dropna(subset=["text"],inplace=True)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()
x=cv.fit_transform(train_df["text"])
x
y=df["category"]

# %%
# train(subset=["text"],inplace=True)
train_df['text']
# Out:
# 2                                     \nIn a word, yes.\n
# 9       :  \n: well, i have lots of experience with sc...
# 14      \nProbably because it IS rape.\n\n\nSo nothing...
# 17      Hello,\ni'm interested in those devices too.\n...
# 20      This is an invitation to send articles to the ...
#                               ...
# 7488    \n\namen.. I too have learned by example, spec...
# 7492    \n: I agree, I had a hard feeling not believin...
# 7496    \n\nYes a flotation tank, combined with florid...
# 7505    Archive-name: atheism/overview\nAlt-atheism-ar...
# 7527    \n   Henry, if I read you correctly, you may b...
# Name: text, Length: 1080, dtype: object

# %%
train_df["text"].isnull().sum()
# Out:
# 0

# %%
from sklearn.naive_bayes import BernoulliNB
bn=BernoulliNB()
bn.fit(x,y)
# Out:
# BernoulliNB()

# %%
x_te=cv.fit_transform(test_df["text"])
y_te=test_df["category"]

# %%
test_df["text"].isnull().sum()
# Out:
# 0

# %%
pred=bn.predict(x_te)

# %%
from sklearn.metrics import accuracy_score
a=accuracy_score(y_te,pred)
a
# Out:
# 0.8157407407407408

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
p=TfidfVectorizer()
x_te=p.fit_transform(train_df["text"])
y_te=df["category"]

# %%
from sklearn.naive_bayes import MultinomialNB
bn=MultinomialNB()
bn.fit(x,y)
# Out:
# MultinomialNB()

# %%
pred=bn.predict(x_te)

# %%
a=accuracy_score(y_te,pred)

# %%
a
# Out:
# 0.9685185185185186
